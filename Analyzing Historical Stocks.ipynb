# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.51-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\pangr\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\pangr\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\pangr\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\pangr\anaconda3\lib\site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\pangr\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\pangr\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\pangr\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.8.tar.gz (948 kB)
#      ---------------------------------------- 0.0/948.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/948.2 kB ? eta -:--:--
#      ---------------------------------------- 10.2/948.2 kB ? eta -:--:--
#       ------------------------------------ 20.5/948.2 kB 330.3 kB/s eta 0:00:03
#      - ----------------------------------- 41.0/948.2 kB 326.8 kB/s eta 0:00:03
#      -- ---------------------------------- 71.7/948.2 kB 393.8 kB/s eta 0:00:03
#      ------ ----------------------------- 163.8/948.2 kB 756.6 kB/s eta 0:00:02
#      -------------- ----------------------- 368.6/948.2 kB 1.5 MB/s eta 0:00:01
#      --------------------------------- ---- 839.7/948.2 kB 3.0 MB/s eta 0:00:01
#      -------------------------------------- 948.2/948.2 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\pangr\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pangr\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\pangr\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\pangr\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pangr\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pangr\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pangr\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pangr\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pangr\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pangr\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Downloading yfinance-0.2.51-py2.py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.7 kB ? eta -:--:--
#    ---------------------------------------- 104.7/104.7 kB 6.3 MB/s eta 0:00:00
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 112.2/112.2 kB 6.4 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.8-py3-none-any.whl size=139012 sha256=5227fe8b383623b586d4b3f9252304d61506d8a78b250aa1513c7f85c8e9a91c
#   Stored in directory: c:\users\pangr\appdata\local\pip\cache\wheels\8f\65\34\456800445efeafb05164fe95285c70e81ba1d96bae30f43917
# Successfully built peewee
# Installing collected packages: peewee, multitasking, html5lib, yfinance
# Successfully installed html5lib-1.1 multitasking-0.0.11 peewee-3.17.8 yfinance-0.2.51
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

tesla_data = yf.download('TSLA', start='2020-01-01', end='2023-01-01')

tesla_data.reset_index(inplace=True)

print(tesla_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  TSLA       TSLA       TSLA       TSLA       TSLA
# 0      2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 1      2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2      2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 3      2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 4      2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
print(tesla_revenue.tail())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(tesla_revenue.tail())
#
# NameError: name 'tesla_revenue' is not defined

# %%
import pandas as pd

tesla_revenue = pd.DataFrame(tesla_data)

tesla_revenue.reset_index(drop=True, inplace=True)

print(tesla_revenue.tail())
# Out:
# Price        Date       Close        High         Low        Open     Volume
# Ticker                   TSLA        TSLA        TSLA        TSLA       TSLA
# 751    2022-12-23  123.150002  128.619995  121.019997  126.370003  166989700
# 752    2022-12-27  109.099998  119.669998  108.760002  117.500000  208643400
# 753    2022-12-28  112.709999  116.269997  108.239998  110.349998  221070500
# 754    2022-12-29  121.820000  123.570000  117.500000  120.389999  221923300
# 755    2022-12-30  123.180000  124.480003  119.750000  119.949997  157777300

# %%
gme_data = yf.download('GME', start='2020-01-01', end='2024-01-01')

gme_data.reset_index(inplace=True)

print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date   Close    High     Low    Open    Volume
# Ticker                GME     GME     GME     GME       GME
# 0      2020-01-02  1.5775  1.6175  1.5175  1.5350  17814400
# 1      2020-01-03  1.4700  1.5625  1.4600  1.5525  14175600
# 2      2020-01-06  1.4625  1.4775  1.4000  1.4500  13579200
# 3      2020-01-07  1.3800  1.4575  1.3600  1.4425  20912000
# 4      2020-01-08  1.4300  1.4625  1.3525  1.3725  22517600

# %%
gme_revenue = pd.DataFrame(gme_data)

# %%
gme_revenue.reset_index(drop=True, inplace=True)
print(gme_revenue.tail())
# Out:
# Price        Date      Close       High        Low       Open   Volume
# Ticker                   GME        GME        GME        GME      GME
# 1001   2023-12-22  16.969999  17.200001  16.450001  16.780001  3325100
# 1002   2023-12-26  17.360001  17.410000  16.820000  16.980000  3079600
# 1003   2023-12-27  18.370001  18.370001  17.370001  17.430000  4800100
# 1004   2023-12-28  18.070000  18.320000  17.850000  18.049999  3574800
# 1005   2023-12-29  17.530001  18.160000  17.459999  18.040001  4524200

# %%
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price', color='green')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price (USD)')
    plt.legend()
    plt.grid()
    plt.show()

make_graph(tesla_data, "Tesla Stock Price (2020-2023)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       8     plt.grid()
#       9     plt.show()
# ---> 11 make_graph(tesla_data, "Tesla Stock Price (2020-2023)")
#
# Cell In[15], line 2, in make_graph(data, title)
#       1 def make_graph(data, title):
# ----> 2     plt.figure(figsize=(10, 6))
#       3     plt.plot(data['Date'], data['Close'], label='Close Price', color='green')
#       4     plt.title(title)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price', color='green')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price (USD)')
    plt.legend()
    plt.grid()
    plt.show()

make_graph(tesla_data, "Tesla Stock Price")

# %%
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price', color='green')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price (USD)')
    plt.legend()
    plt.grid()
    plt.show()

make_graph(gme_data, "Gamestop Stock Price")
